// %%
USE {
    repositories {
        mavenLocal()
    }
    dependencies {
        implementation("sk.ainet.graphviz:graphviz-jvm:0.0.1")
    }
}

// %%
import org.graphviz.kotlin.GraphvizLibrary

// %%
GraphvizLibrary.SUPPORTED_PLATFORMS
// Out:
// [JVM, Android, iOS, JavaScript]

// %%
import org.graphviz.kotlin.builder.GraphBuilder
import org.graphviz.kotlin.generator.DotGenerator
import org.graphviz.kotlin.model.Point

val graph = GraphBuilder(id = "G", isDirected = true)
    .apply {
        node("A") {
            position(0.0, 0.0)
            label("A")
        }
        node("B") {
            position(120.0, 60.0)
            label("B")
        }
        edge("A", "B") {
            // For a straight line, you can just use the node positions as control points
            controlPoints(listOf(
                Point(0.0, 0.0),
                Point(120.0, 60.0)
            ))
            label("A -> B")
        }
    }
    .build()

val dot = DotGenerator.generate(graph)

// %%
import org.graphviz.kotlin.dsl.digraph

val graph = digraph("wx_plus_b") {
    // Layout left-to-right for readability
    attribute("rankdir", "LR")

    // Nodes
    node("x") { label("x (input)") }
    node("w") { label("w (weight)") }
    node("b") { label("b (bias)") }
    node("y") { label("y (output)\n y = w*x + b") }

    // Intermediate (implicit) multiply and add shown via labeled edges to y
    // Edge x -> y labeled with the weight multiplier w
    edge("x", "y") { label("* w") }

    // Edge b -> y labeled with + b to indicate bias addition
    edge("b", "y") { label("+ b") }

    // Optional styling
    attribute("labelloc", "t")
    attribute("label", "MLP linear unit: y = w·x + b")
}

// %%
graph
// Out:
// GraphImpl(id=wx_plus_b, isDirected=true, nodes=[NodeImpl(id=x, attributes=AttributeMap({label=StringValue(value=x (input))}), position=null), NodeImpl(id=w, attributes=AttributeMap({label=StringValue(value=w (weight))}), position=null), NodeImpl(id=b, attributes=AttributeMap({label=StringValue(value=b (bias))}), position=null), NodeImpl(id=y, attributes=AttributeMap({label=StringValue(value=y (output)
//  y = w*x + b)}), position=null)], edges=[EdgeImpl(source=NodeImpl(id=x, attributes=AttributeMap({label=StringValue(value=x (input))}), position=null), target=NodeImpl(id=y, attributes=AttributeMap({label=StringValue(value=y (output)
//  y = w*x + b)}), position=null), attributes=AttributeMap({label=StringValue(value=* w)}), controlPoints=[]), EdgeImpl(source=NodeImpl(id=b, attributes=AttributeMap({label=StringValue(value=b (bias))}), position=null), target=NodeImpl(id=y, attributes=AttributeMap({label=StringValue(value=y (output)
//  y = w*x + b)}), position=null), attributes=AttributeMap({label=StringValue(value=+ b)}), controlPoints=[])], subgraphs=[], attributes=AttributeMap({rankdir=StringValue(value=LR), labelloc=StringValue(value=t), label=StringValue(value=MLP linear unit: y = w·x + b)}))

// %%
import org.graphviz.kotlin.renderer.DefaultSvgRenderer
import org.graphviz.kotlin.renderer.RenderOptions

val renderer = DefaultSvgRenderer()
val svg: String = renderer.render(graph, RenderOptions.default())

println(svg)
// Out:
// <?xml version="1.0" encoding="UTF-8"?>
// <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN" "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
// <svg width="264" height="115" viewBox="-20 -20 264 115" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" version="1.1" preserveAspectRatio="xMidYMid meet">
//   <metadata>
//     <generator>Graphviz Kotlin Multiplatform</generator>
//     <graph-id>wx_plus_b</graph-id>
//     <graph-type>directed</graph-type>
//   </metadata>
//   <style type="text/css">
//     <![CDATA[
//       /* Default Graphviz styles */
//       .node { fill: white; stroke: black; stroke-width: 1; }
//       .edge { fill: none; stroke: black; stroke-width: 1; }
//       .text { font-family: Arial, sans-serif; font-size: 12.0px; text-anchor: middle; dominant-baseline: central; }
//       .background { fill: none; }
//       .graph { }
//       .cluster { fill: none; stroke: black; stroke-width: 1; }
//     ]]>
//   </style>
//   <g transform="translate(20.0, 95.0) scale(1.0, -1.0)" class="graph-content">
//     <ellipse cx="108.0" cy="0.0" rx="30.0" ry="15.0" class="node" id="node-x"/>
//     <text x="108.0" y="0.0" class="node-text" text-anchor="middle" dominant-baseline="central" id="node-x-label">x (input)</text>
//     <ellipse cx="224.0" cy="0.0" rx="30.0" ry="15.0" class="node" id="node-w"/>
//     <text x="224.0" y="0.0" class="node-text" text-anchor="middle" dominant-baseline="central" id="node-w-label">w (weight)</text>
//     <ellipse cx="0.0" cy="0.0" rx="30.0" ry="15.0" class="node" id="node-b"/>
//     <text x="0.0" y="0.0" class="node-text" text-anchor="middle" dominant-baseline="central" id="node-b-label">b (bias)</text>
//     <ellipse cx="60.0" cy="75.0" rx="30.0" ry="15.0" class="node" id="node-y"/>
//     <text x="60.0" y="75.0" class="node-text" text-anchor="middle" dominant-baseline="central" id="node-y-label">y (output)
//  y = w*x + b</text>
//     <path d="M 108.0 0.0 L 60.0 75.0" stroke="black" stroke-width="1" class="edge" id="edge-x-y" fill="none"/>
//     <polygon points="60.0,75.0 60.45698494775785,65.01044721934346 68.87969895437297,70.40098418357714" class="arrowhead" fill="black" stroke="black"/>
//     <text x="84.0" y="37.5" class="edge-label" text-anchor="middle" dominant-baseline="central" id="edge-x-y-label" fill="black">* w</text>
//     <path d="M 0.0 0.0 L 60.0 75.0" stroke="black" stroke-width="1" class="edge" id="edge-b-y" fill="none"/>
//     <polygon points="60.0,75.0 50.685638144780256,71.36095297776637 58.49432623921056,65.11400250222214" class="arrowhead" fill="black" stroke="black"/>
//     <text x="30.0" y="37.5" class="edge-label" text-anchor="middle" dominant-baseline="central" id="edge-b-y-label" fill="black">+ b</text>
//   </g>
// </svg>
