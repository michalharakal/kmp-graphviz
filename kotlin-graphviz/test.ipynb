// %%
USE {
    repositories {
        mavenLocal()
    }
    dependencies {
        implementation("sk.ainet.graphviz:graphviz-jvm:0.0.1")
    }
}

// %%
import org.graphviz.kotlin.GraphvizLibrary

// %%
GraphvizLibrary.SUPPORTED_PLATFORMS
// Out:
// [JVM, Android, iOS, JavaScript]

// %%
import org.graphviz.kotlin.builder.GraphBuilder
import org.graphviz.kotlin.generator.DotGenerator
import org.graphviz.kotlin.model.Point

val graph = GraphBuilder(id = "G", isDirected = true)
    .apply {
        node("A") {
            position(0.0, 0.0)
            label("A")
        }
        node("B") {
            position(120.0, 60.0)
            label("B")
        }
        edge("A", "B") {
            // For a straight line, you can just use the node positions as control points
            controlPoints(listOf(
                Point(0.0, 0.0),
                Point(120.0, 60.0)
            ))
            label("A -> B")
        }
    }
    .build()

val dot = DotGenerator.generate(graph)

// %%
dot
// Out:
// digraph G {
//   A [label="A"];
//   B [label="B"];
//   A -> B [label="A -> B"];
// }

// %%
import org.graphviz.kotlin.renderer.DefaultSvgRenderer
import org.graphviz.kotlin.renderer.RenderOptions

val renderer = DefaultSvgRenderer()
val svg: String = renderer.render(graph, RenderOptions.default())

println(svg)
// Out:
// <?xml version="1.0" encoding="UTF-8"?>
// <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN" "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
// <svg width="160" height="100" viewBox="-20 -20 160 100" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" version="1.1" preserveAspectRatio="xMidYMid meet">
//   <metadata>
//     <generator>Graphviz Kotlin Multiplatform</generator>
//     <graph-id>G</graph-id>
//     <graph-type>directed</graph-type>
//   </metadata>
//   <style type="text/css">
//     <![CDATA[
//       /* Default Graphviz styles */
//       .node { fill: white; stroke: black; stroke-width: 1; }
//       .edge { fill: none; stroke: black; stroke-width: 1; }
//       .text { font-family: Arial, sans-serif; font-size: 12.0px; text-anchor: middle; dominant-baseline: central; }
//       .background { fill: none; }
//       .graph { }
//       .cluster { fill: none; stroke: black; stroke-width: 1; }
//     ]]>
//   </style>
//   <g transform="translate(20.0, 80.0) scale(1.0, -1.0)" class="graph-content">
//     <ellipse cx="0.0" cy="0.0" rx="30.0" ry="15.0" class="node" id="node-A"/>
//     <text x="0.0" y="0.0" class="node-text" text-anchor="middle" dominant-baseline="central" id="node-A-label">A</text>
//     <ellipse cx="120.0" cy="60.0" rx="30.0" ry="15.0" class="node" id="node-B"/>
//     <text x="120.0" y="60.0" class="node-text" text-anchor="middle" dominant-baseline="central" id="node-B-label">B</text>
//     <path d="M 0.0 0.0 L 120.0 60.0" stroke="black" stroke-width="1" class="edge" id="edge-A-B" fill="none"/>
//     <polygon points="120.0,60.0 110.01796533008537,60.59915260879216 114.49010128508496,51.65488069879301" class="arrowhead" fill="black" stroke="black"/>
//     <text x="60.0" y="30.0" class="edge-label" text-anchor="middle" dominant-baseline="central" id="edge-A-B-label" fill="black">A -&gt; B</text>
//   </g>
// </svg>
